# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import pingouin as pg
import sys
import reverse_geocode

# Create a dictionary of versions
versions = {
    "Python": sys.version.split()[0],
    "Pandas": pd.__version__,
    "NumPy": np.__version__,
    "Matplotlib": plt.matplotlib.__version__,
    "Seaborn": sns.__version__,
    "Statsmodels": sm.__version__,
    "Pingouin": pg.__version__
}

# Display as a clean DataFrame
df_versions = pd.DataFrame(list(versions.items()), columns=['Library', 'Version'])
df_versions
# Out:
#        Library Version
# 0       Python  3.13.9
# 1       Pandas   2.3.3
# 2        NumPy   2.3.4
# 3   Matplotlib  3.10.7
# 4      Seaborn  0.13.2
# 5  Statsmodels  0.14.5
# 6     Pingouin   0.5.5

# %% [markdown]
# ## Read Data

# %%
# read csv
df = pd.read_csv("../Data/Crimes_2001_to_Present_20251226.csv")

# %%
# display all columns
pd.set_option('display.max_columns', None)

# display
df.head()

# reset options
# pd.reset_option('display.max_columns')
# Out:
#          ID Case Number                    Date                     Block  \
# 0  14059178    JJ526784  12/18/2025 12:00:00 AM       070XX S CHAPPEL AVE
# 1  14059785    JJ527520  12/18/2025 12:00:00 AM         085XX S DANTE AVE
# 2  14062578    JJ530929  12/18/2025 12:00:00 AM          077XX S GREEN ST
# 3  14063828    JJ532379  12/18/2025 12:00:00 AM  048XX W BELLE PLAINE AVE
# 4  14059235    JJ526636  12/18/2025 12:00:00 AM           029XX W POLK ST
#
#    IUCR             Primary Type              Description  \
# 0  2825            OTHER OFFENSE  HARASSMENT BY TELEPHONE
# 1  0820                    THEFT           $500 AND UNDER
# 2  0820                    THEFT           $500 AND UNDER
# 3  0910      MOTOR VEHICLE THEFT               AUTOMOBILE
# 4  0281  CRIMINAL SEXUAL ASSAULT           NON-AGGRAVATED
#
#               Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                        RESIDENCE   False      True   331       3.0   5.0
# 1                           STREET   False     False   412       4.0   8.0
# 2  RESIDENCE - YARD (FRONT / BACK)   False     False   621       6.0  17.0
# 3                           STREET   False     False  1624      16.0  45.0
# 4                        APARTMENT   False     False  1135      11.0  28.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0            43.0       26     1191097.0     1858637.0  2025
# 1            45.0       06     1187355.0     1848745.0  2025
# 2            71.0       06     1171977.0     1853575.0  2025
# 3            15.0       07     1143338.0     1926819.0  2025
# 4            27.0       02     1156879.0     1896229.0  2025
#
#                Updated On   Latitude  Longitude                       Location
# 0  12/25/2025 03:41:39 PM  41.767109 -87.575104    (41.7671089, -87.575103515)
# 1  12/25/2025 03:41:39 PM  41.740054 -87.589133   (41.74005402, -87.589132903)
# 2  12/25/2025 03:41:39 PM  41.753659 -87.645334   (41.753659288, -87.64533412)
# 3  12/25/2025 03:41:39 PM  41.955231 -87.748459  (41.955231253, -87.748458925)
# 4  12/25/2025 03:41:39 PM  41.871025 -87.699510  (41.871025414, -87.699510379)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8466423 entries, 0 to 8466422
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# dtypes: bool(2), float64(7), int64(3), object(10)
# memory usage: 1.3+ GB

# %%
df.shape
# Out:
# (8466423, 22)

# %%
def

# %%
df[(df['Primary Type'].str.contains('HOMICIDE', case=False, na=False)) & (df.Year == 2025)]

# %%
# coordinates = [(41.894491615, -87.718722846)] # Example coordinates (lat, long)

coordinates = (41.722434522, -87.632168804)  # Single tuple
location_info = reverse_geocode.get(coordinates)
print(location_info)
# Out:
# {'country_code': 'US', 'city': 'Chatham', 'latitude': 41.74115, 'longitude': -87.61255, 'population': 31392, 'state': 'Illinois', 'county': 'Cook County', 'country': 'United States'}

# %%
location_info.get('city', np.nan)
# Out:
# 'West Garfield Park'

# %%
def extract_address(row):
    try:
        location = geolocator.reverse((row['Latitude'], row['Longitude']))
        addr = location.raw['address']
        return {
            'neighborhood': addr.get('neighbourhood', ''),
            'city': addr.get('city', ''),
            'county': addr.get('county', ''),
            'state': addr.get('state', '')
        }
    except:
        return {'neighborhood': 'Unknown', 'city': '', 'county': '', 'state': ''}

df[['neigh', 'city', 'county', 'state']] = pd.json_normalize(
    df[['Latitude', 'Longitude']].head(50).apply(extract_address, axis=1)
)

# %%
# Initialize geocoder (free, no API key)
geolocator = Nominatim(user_agent="crime_analyzer")

# Single coordinate (Chicago example)
lat, lon = 41.955231, -87.748459
location = geolocator.reverse((lat, lon))
print(location.address)  
print(location.raw['address'])
# Out:
# 4824, West Belle Plaine Avenue, Grayland, Portage Park, Chicago, Jefferson Township, Cook County, Illinois, 60641, United States
# {'house_number': '4824', 'road': 'West Belle Plaine Avenue', 'neighbourhood': 'Grayland', 'suburb': 'Portage Park', 'city': 'Chicago', 'municipality': 'Jefferson Township', 'county': 'Cook County', 'state': 'Illinois', 'ISO3166-2-lvl4': 'US-IL', 'postcode': '60641', 'country': 'United States', 'country_code': 'us'}

# %%
# Initialize geocoder (free, no API key)
geolocator = Nominatim(user_agent="crime_analyzer")

# Single coordinate (Chicago example)
lat, lon = 41.871025,	-87.699510
location = geolocator.reverse((lat, lon))
print(location.address)  
print(location.raw['address'])
# Out:
# 2922, West Polk Street, East Garfield Park, Chicago, West Chicago Township, Cook County, Illinois, 60624, United States
# {'house_number': '2922', 'road': 'West Polk Street', 'suburb': 'East Garfield Park', 'city': 'Chicago', 'municipality': 'West Chicago Township', 'county': 'Cook County', 'state': 'Illinois', 'ISO3166-2-lvl4': 'US-IL', 'postcode': '60624', 'country': 'United States', 'country_code': 'us'}

# %%
location.raw['address']
# Out:
# {'house_number': '2922',
#  'road': 'West Polk Street',
#  'suburb': 'East Garfield Park',
#  'city': 'Chicago',
#  'municipality': 'West Chicago Township',
#  'county': 'Cook County',
#  'state': 'Illinois',
#  'ISO3166-2-lvl4': 'US-IL',
#  'postcode': '60624',
#  'country': 'United States',
#  'country_code': 'us'}

# %%
address = location.raw['address']
address
# Out:
# {'house_number': '4824',
#  'road': 'West Belle Plaine Avenue',
#  'neighbourhood': 'Grayland',
#  'suburb': 'Portage Park',
#  'city': 'Chicago',
#  'municipality': 'Jefferson Township',
#  'county': 'Cook County',
#  'state': 'Illinois',
#  'ISO3166-2-lvl4': 'US-IL',
#  'postcode': '60641',
#  'country': 'United States',
#  'country_code': 'us'}

# %%
address.get('neighbourhood', 'N/A')
# Out:
# 'Grayland'

# %%
# Crime type per year
df.groupby([df.Year, 'Primary Type']).size().unstack(fill_value=0)
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Year
# 2001           1011    31388    93471     26014
# 2002           1032    31524    94152     25623
# 2003            955    29477    88380     25157
# 2004            778    28850    87135     24564
# 2005            691    27067    83964     25503
# 2006            726    25945    80666     24324
# 2007            712    26313    79595     24858
# 2008            644    25448    75930     26218
# 2009            616    22861    68460     26767
# 2010            522    21537    65403     26422
# 2011            504    20411    60460     26620
# 2012            469    19900    59132     22844
# 2013            364    17972    54006     17894
# 2014            397    16903    49455     14569
# 2015            453    17048    48926     13184
# 2016            516    18743    50300     14289
# 2017            444    19306    49240     13001
# 2018            373    20408    49833     11747
# 2019            376    20624    49525      9639
# 2020            588    18260    41517      8759
# 2021            530    20344    40484      6661
# 2022            422    20813    40965      7595
# 2023            513    22631    44251      7487
# 2024            481    23477    46133      8428
# 2025            363    20889    41130      9277
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Year
# 2001                                          1                 1770
# 2002                                          0                 1800
# 2003                                          0                 1563
# 2004                                          0                 1524
# 2005                                          0                 1509
# 2006                                          0                 1427
# 2007                                          0                 1498
# 2008                                          0                 1500
# 2009                                          0                 1390
# 2010                                          0                 1319
# 2011                                          0                 1441
# 2012                                          0                 1378
# 2013                                          0                 1251
# 2014                                         15                 1292
# 2015                                         34                 1323
# 2016                                         36                 1469
# 2017                                         69                 1466
# 2018                                        149                 1375
# 2019                                        217                  898
# 2020                                        148                   75
# 2021                                        173                    0
# 2022                                        177                    0
# 2023                                        205                    0
# 2024                                        196                    0
# 2025                                        266                    0
#
# Primary Type  CRIMINAL DAMAGE  CRIMINAL SEXUAL ASSAULT  CRIMINAL TRESPASS  \
# Year
# 2001                    55865                       47              13242
# 2002                    55942                       39              13881
# 2003                    55011                       54              14807
# 2004                    53164                       59              15913
# 2005                    54548                       53              16655
# 2006                    57124                       61              14505
# 2007                    53749                       67              13699
# 2008                    52843                       67              12310
# 2009                    47725                       61              10851
# 2010                    40654                       79               9401
# 2011                    37331                       75               8659
# 2012                    35855                       92               8216
# 2013                    30856                      104               8136
# 2014                    27799                      106               7539
# 2015                    28677                      139               6401
# 2016                    31018                      158               6306
# 2017                    29045                      234               6814
# 2018                    27823                      372               6909
# 2019                    26683                      775               6819
# 2020                    24882                     1182               4176
# 2021                    25095                     1536               3406
# 2022                    27250                     1612               4223
# 2023                    30094                     1675               4720
# 2024                    28555                     1604               4951
# 2025                    25135                     1574               5121
#
# Primary Type  DECEPTIVE PRACTICE  ...  OTHER OFFENSE  PROSTITUTION  \
# Year                              ...
# 2001                       14959  ...          29669          6026
# 2002                       13740  ...          32602          6408
# 2003                       13464  ...          31149          6214
# 2004                       13263  ...          29533          7476
# 2005                       13592  ...          28028          6124
# 2006                       13612  ...          27101          7034
# 2007                       14180  ...          26863          6087
# 2008                       14943  ...          26532          5141
# 2009                       13895  ...          25601          3940
# 2010                       12592  ...          22012          2484
# 2011                       12752  ...          20207          2424
# 2012                       13790  ...          17524          2204
# 2013                       13946  ...          18051          1652
# 2014                       15994  ...          17020          1625
# 2015                       16489  ...          17566          1322
# 2016                       19437  ...          17309           800
# 2017                       19804  ...          17272           735
# 2018                       19985  ...          17272           718
# 2019                       19278  ...          16806           681
# 2020                       18612  ...          12611           277
# 2021                       17915  ...          13959            95
# 2022                       17112  ...          14622           283
# 2023                       17463  ...          15729           209
# 2024                       16164  ...          17114           307
# 2025                       13748  ...          16065           188
#
# Primary Type  PUBLIC INDECENCY  PUBLIC PEACE VIOLATION  RITUALISM  ROBBERY  \
# Year
# 2001                         9                    2750          8    18441
# 2002                         8                    2457          2    18523
# 2003                         6                    2430          2    17332
# 2004                         9                    2495          1    15978
# 2005                         4                    2730          2    16047
# 2006                         4                    3068          7    15969
# 2007                         5                    3315          1    15450
# 2008                         4                    3013          0    16703
# 2009                        10                    3147          0    15981
# 2010                         7                    3538          0    14275
# 2011                        13                    3095          0    13983
# 2012                        17                    3007          0    13484
# 2013                        10                    3135          0    11819
# 2014                        10                    2903          0     9800
# 2015                        14                    2422          0     9638
# 2016                        10                    1607          0    11960
# 2017                        10                    1498          0    11881
# 2018                        14                    1372          0     9681
# 2019                        11                    1520          0     7995
# 2020                         9                    1272          1     7855
# 2021                         4                     603          0     7920
# 2022                         5                     712          0     8964
# 2023                         6                     862          0    11051
# 2024                         9                     979          0     9116
# 2025                        10                    1027          0     5656
#
# Primary Type  SEX OFFENSE  STALKING  THEFT  WEAPONS VIOLATION
# Year
# 2001                 2238       204  99291               4278
# 2002                 2173       200  98334               4282
# 2003                 2079       247  98876               4211
# 2004                 1805       215  95464               4298
# 2005                 1820       192  85684               4106
# 2006                 1576       186  86241               3821
# 2007                 1531       213  85156               3554
# 2008                 1504       190  88437               3877
# 2009                 1268       168  80977               4159
# 2010                 1145       189  76758               3704
# 2011                 1097       182  75153               3880
# 2012                 1089       207  75464               3907
# 2013                 1062       154  71536               3245
# 2014                 1026       142  61569               3113
# 2015                 1052       155  57353               3364
# 2016                 1062       176  61627               3450
# 2017                 1074       192  64387               4686
# 2018                 1270       208  65290               5456
# 2019                 1383       228  62499               6339
# 2020                  988       204  41353               8433
# 2021                 1120       370  40823               8979
# 2022                 1237       454  54900               8781
# 2023                 1364       531  57503               8608
# 2024                 1250       517  60526               7839
# 2025                 1239       544  52813               5296
#
# [25 rows x 34 columns]

# %%
df["Primary Type"].value_counts()
# Out:
# Primary Type
# THEFT                                1798014
# BATTERY                              1542513
# CRIMINAL DAMAGE                       962723
# NARCOTICS                             764952
# ASSAULT                               568139
# OTHER OFFENSE                         528217
# BURGLARY                              447444
# MOTOR VEHICLE THEFT                   434045
# DECEPTIVE PRACTICE                    390729
# ROBBERY                               315502
# CRIMINAL TRESPASS                     227660
# WEAPONS VIOLATION                     125666
# PROSTITUTION                           70454
# OFFENSE INVOLVING CHILDREN             60756
# PUBLIC PEACE VIOLATION                 54957
# SEX OFFENSE                            34452
# CRIM SEXUAL ASSAULT                    27268
# INTERFERENCE WITH PUBLIC OFFICER       20371
# LIQUOR LAW VIOLATION                   15418
# GAMBLING                               14666
# ARSON                                  14480
# HOMICIDE                               14050
# CRIMINAL SEXUAL ASSAULT                11825
# KIDNAPPING                              7506
# STALKING                                6268
# INTIMIDATION                            5131
# CONCEALED CARRY LICENSE VIOLATION       1686
# OBSCENITY                                961
# PUBLIC INDECENCY                         218
# OTHER NARCOTIC VIOLATION                 164
# HUMAN TRAFFICKING                        137
# NON-CRIMINAL                              26
# RITUALISM                                 24
# DOMESTIC VIOLENCE                          1
# Name: count, dtype: int64

# %%
df.Year.unique()
# Out:
# array([2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015,
#        2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
#        2003, 2002, 2001])

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8466423 entries, 0 to 8466422
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# dtypes: bool(2), float64(7), int64(3), object(10)
# memory usage: 1.3+ GB

# %%
# Simulate crime data: 3 neighborhood types (urban, suburban, rural), n=100 each
np.random.seed(1776)
urban = np.random.normal(45, 5, 100)      # High crime
suburban = np.random.normal(20, 4, 100)   # Medium
rural = np.random.normal(5, 2, 100)       # Low

df = pd.DataFrame({
    'burglaries': np.concatenate([urban, suburban, rural]),
    'neighborhood': np.repeat(['urban', 'suburban', 'rural'], 100)
})

df.head()
# Out:
#    burglaries neighborhood
# 0   45.059813        urban
# 1   39.207040        urban
# 2   48.228861        urban
# 3   38.516195        urban
# 4   44.272430        urban

# %% [markdown]
# ### Descriptives and Visualization

# %%
# Summary stats by group
print(pg.descriptives('burglaries', data=df, groupby='neighborhood'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Summary stats by group
# ----> 2 print(pg.descriptives('burglaries', data=df, groupby='neighborhood'))
#
# AttributeError: module 'pingouin' has no attribute 'descriptives'

# %%
# Summary stats by group
print(pg.descriptives('burglaries', data=df, groupby='neighborhood'))

# Boxplot (reveals clear separation)
sns.boxplot(data=df, x='neighborhood', y='burglaries')
plt.title('Burglary Rates by Neighborhood Type')
plt.show()

# %%
# Check Assumptions
# Normality
print('Normality Test:')
print(pg.normality(df, dv='burglaries', group='neighborhood'))
# Out:
# Normality Test:
#                      W      pval  normal
# neighborhood
# urban         0.991969  0.818999    True
# suburban      0.987801  0.493632    True
# rural         0.992402  0.849560    True

# %%
# Variance
print("\nVariance Test:")
print(pg.homoscedasticity(df, dv='burglaries', group = 'neighborhood'))
# Out:
# Variance Test:
#                W          pval  equal_var
# levene  17.16964  8.786251e-08      False

# %%
# Robust ANOVA (Welch's)
aov = pg.welch_anova(dv='burglaries', between='neighborhood', data = df)
print("\nWelch's ANOVA Rersults:")
print(aov)
# Out:
# Welch's ANOVA Rersults:
#          Source  ddof1      ddof2            F          p-unc       np2
# 0  neighborhood      2  177.20733  4058.268877  1.018697e-148  0.954216
